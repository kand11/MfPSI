# %% [markdown]
# <a href="https://colab.research.google.com/github/kand11/MfPSI/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def sigmoid(x):
  # Наша функция активации: f(x) = 1 / (1 + e^(-x))
  return 1 / (1 + np.exp(-x))

def deriv_sigmoid(x):
  # Производная сигмоиды: f'(x) = f(x) * (1 - f(x))
  fx = sigmoid(x)
  return fx * (1 - fx)

def mse_loss(y_true, y_pred):
  # y_true и y_pred - массивы numpy одинаковой длины.
  return ((y_true - y_pred) ** 2).mean()

# %%
class Neuron:
  def __init__(self):
        # Веса
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    self.w3 = np.random.normal()
    self.w4 = np.random.normal()

    # Пороги
    self.b1 = np.random.normal()
    self.b2 = np.random.normal()

  def feedforward(self, x):
  # x is a numpy array with 2 elements.
    h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1)
    o1 = sigmoid(self.w3 * h1 + self.b2)
    return o1

  def train(self, data, all_y_trues):
    learn_rate = 0.1
    epochs = 5000 # сколько раз пройти по всему набору данных

    for epoch in range(epochs):
      for x, y_true in zip(data, all_y_trues):
        # --- Прямой проход (эти значения нам понадобятся позже)
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = sigmoid(sum_h1)

        sum_o1 = self.w3 * h1 + self.b2
        o1 = sigmoid(sum_o1)
        y_pred = o1

        # --- Считаем частные производные.
        # --- Имена: d_L_d_w1 = "частная производная L по w1"
        d_L_d_ypred = -2 * (y_true - y_pred)

        # Нейрон o1
        d_ypred_d_w3 = h1 * deriv_sigmoid(sum_o1)
        d_ypred_d_b2 = deriv_sigmoid(sum_o1)

        d_ypred_d_h1 = self.w3 * deriv_sigmoid(sum_o1)

        # Нейрон h1
        d_h1_d_w1 = x[0] * deriv_sigmoid(sum_h1)
        d_h1_d_w2 = x[1] * deriv_sigmoid(sum_h1)
        d_h1_d_b1 = deriv_sigmoid(sum_h1)


        # --- Обновляем веса и пороги
        # Нейрон h1
        self.w1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w1
        self.w2 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w2
        self.b1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_b1


        # Нейрон o1
        self.w3 -= learn_rate * d_L_d_ypred * d_ypred_d_w3
        self.b2 -= learn_rate * d_L_d_ypred * d_ypred_d_b2

      # --- Считаем полные потери в конце каждой эпохи
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        loss = mse_loss(all_y_trues, y_preds)
        print("Epoch %d loss: %.3f" % (epoch, loss))

# %%
# Обучающие данные для функции OR
training_data = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
training_labels = np.array([0, 1, 1, 1])

neuron = Neuron()
neuron.train(training_data, training_labels)
# Out:
# Epoch 0 loss: 0.241
# Epoch 10 loss: 0.240
# Epoch 20 loss: 0.240
# Epoch 30 loss: 0.239
# Epoch 40 loss: 0.239
# Epoch 50 loss: 0.238
# Epoch 60 loss: 0.237
# Epoch 70 loss: 0.236
# Epoch 80 loss: 0.235
# Epoch 90 loss: 0.234
# Epoch 100 loss: 0.233
# Epoch 110 loss: 0.231
# Epoch 120 loss: 0.229
# Epoch 130 loss: 0.227
# Epoch 140 loss: 0.225
# Epoch 150 loss: 0.222
# Epoch 160 loss: 0.219
# Epoch 170 loss: 0.215
# Epoch 180 loss: 0.211
# Epoch 190 loss: 0.207
# Epoch 200 loss: 0.203
# Epoch 210 loss: 0.198
# Epoch 220 loss: 0.194
# Epoch 230 loss: 0.191
# Epoch 240 loss: 0.189
# Epoch 250 loss: 0.188
# Epoch 260 loss: 0.187
# Epoch 270 loss: 0.186
# Epoch 280 loss: 0.186
# Epoch 290 loss: 0.185
# Epoch 300 loss: 0.185
# Epoch 310 loss: 0.185
# Epoch 320 loss: 0.184
# Epoch 330 loss: 0.184
# Epoch 340 loss: 0.184
# Epoch 350 loss: 0.183
# Epoch 360 loss: 0.183
# Epoch 370 loss: 0.183
# Epoch 380 loss: 0.182
# Epoch 390 loss: 0.182
# Epoch 400 loss: 0.181
# Epoch 410 loss: 0.181
# ...

# %%
# Делаем пару предсказаний
first_test = np.array([1, 0])
second_test = np.array([0, 1])
third_test = np.array([0, 0])
print("1 или 0: %.3f" % neuron.feedforward(first_test))
print("0 или 1: %.3f" % neuron.feedforward(second_test))
print("0 или 0: %.3f" % neuron.feedforward(third_test))
# Out:
# 1 или 0: 0.972
# 0 или 1: 0.972
# 0 или 0: 0.049
